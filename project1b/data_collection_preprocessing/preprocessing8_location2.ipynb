# %%
# get country
# get zip and city
# then get state and geolocation

# %%
import pandas as pd
import re
from uszipcode import ZipcodeSearchEngine # main
# http://pythonhosted.org/uszipcode/
import zipcode # sub
# https://pypi.python.org/pypi/zipcode
data = pd.read_csv("article_after_processing7.csv", encoding='iso-8859-1')

# %%
# get the countries with the top 30 highest GDP
country = pd.read_csv("countries_w_gdp.csv", encoding='iso-8859-1')
country_list = country.Country[0:100]

# %%
def get_zipcode(address):
    regex = re.compile(r'\s(\d{5})\s*')
    match = re.search(regex, address)
    if match:
        return match.group(1)
    else:
        return "not found"
    
data["zip_code"] = data.Location.apply(lambda address: get_zipcode(str(address)))

# %%
def get_city(zip_code):
    search = ZipcodeSearchEngine()
    if zip_code != "not found":
        myzip = search.by_zipcode(zip_code)
        if myzip:
            return myzip["City"]
        else:
            myzip = zipcode.isequal(zip_code)
            if myzip:
                return myzip.city
        
data["City"] = data.zip_code.apply(lambda zip_code: get_city(zip_code))

# %%
def check_city_match(row):
    if row["City"] != None:
        regex = re.compile(r'{}'.format(row["City"]), flags = re.I)
        match = re.search(regex, row["Location"])
        if match:
            return True
        else:
            return False
    else:
        return False


data["address_check"] = data.apply(lambda row: check_city_match(row), axis = 1)

# %%
data[ data["address_check"] == False][["Location","zip_code" ,"City"]]
# Out:
#                                               Location   zip_code  \
# 0    Gokaldas Chambers, 3rd Floor, 5th Main, Bellar...      56008
# 1    6th Floor, New Penderel House 283-288 High Hol...  not found
# 3    6 Ramillies Street London, W1F 7TY United Kingdom  not found
# 5          Sonnenburger Str. 73, 10437 Berlin, Germany      10437
# 9         47 E. All Saints Frederick, MD United States  not found
# 10   Sovereign House Church Street Brighton, East S...  not found
# 14   The River Building - Level 1 Cannon Bridge Hou...  not found
# 16   BankBazaar.com (A & A Dukaan Financial Service...      60000
# 20    Max-Beer-Strasse, 2 Berlin, Berlin 10119 Germany      10119
# 23          PrannerstraÃ?e 2-4 MÃ¼nchen, 80333 Germany      80333
# 27   7500 W Sunrise Blvd Plantation, Florida 33322 ...      33322
# 28   5F Building D BenQ Plaza 207 Songhong Rd. Chan...      20033
# 34   Swamy Vivekananda Road Kadiranapalya, Sarvagna...      56003
# 42        Rochdelskaya str. Moscow, Russian Federation  not found
# 44                                       United States  not found
# 45   76, boulevard de la RÃ©publique Boulogne, 9210...      92100
# 46   Rua Siqueira Campos 43 Rio de Janeiro, RJ 2203...      22031
# 48   3rd Floor Brettenham House 5 Lancaster Place L...  not found
# 51           Ocean Front Walk Venice, CA United States  not found
# 59   10075 Westmoor Drive Suite 200 Westminster, CO...      80021
# 60   12130 Millennium Drive Los Angeles, CA 90094 U...      90094
# 66         Greater London House London, United Kingdom  not found
# 75   150 Elgin St. 8th Floor Ottawa, ON K1N 5T5 Canada  not found
# 77                             N/A Montreal, Qc Canada  not found
# 79   Urban Bench 10th, Teheranro 325 Gangnamgu Seou...  not found
# 80                   . San Francisco, CA United States  not found
# 84       525 Coventry Rd Ottawa, Ontario K1K2C5 Canada  not found
# 87   7F Azabudai Hinoki Building 3-1-5 Azabudai, Mi...  not found
# 89                                       United States  not found
# 92   #04-08/09, Block 79 Ayer Rajah Crescent Singap...      13995
# ..                                                 ...        ...
# 128  Unit 2.0, 8 Scrubs Lane London, United Kingdom...  not found
# 131  2513 E. Charleston Rd Palo Alto, California 94...      94043
# 132          RitterstraÃ?e 12-14 Berlin, 10969 Germany      10969
# 134  101 S. Hanley Rd Suite 300 St. Louis, MO 63105...      63105
# 140                                         ,   Israel  not found
# 150   49 Spadina Ave #303, Toronto, ON M5V 2J1, Canada  not found
# 153                    San Francisco, CA United States  not found
# 154    13-19 Vine Hill London, EC1R 5DW United Kingdom  not found
# 155  Ludwig-Erhard-StraÃ?e 1 Hamburg, Hamburg 20459...      20459
# 162                                 Ulm, 89081 Germany      89081
# 171              Kungsgatan 15 Stockholm, 11143 Sweden      11143
# 174  100 Pasir Panjang Road, #06-07 Singapore, 1185...      11851
# 176  JÃ¼licher StraÃ?e 344 Aachen, Deutschland 5207...      52070
# 184                       Torggata 8 Oslo, 0181 Norway  not found
# 185         San Francisco CA, California United States  not found
# 187  2nd Floor, Aldgate Tower 2 Leman Street  Londo...  not found
# 188     Plot 5,sector 44 Gurgaon, Haryana 122002 India      12200
# 189                       San Mateo, CA, United States  not found
# 195  Second Floor, The Ferry Building 99 Quay Stree...  not found
# 197                                      United States  not found
# 198  39 Earlham Street London, WC2H 9LT United Kingdom  not found
# 201                       Via Polesine 13 Milan, Italy  not found
# 207  28-30 Kirby Street London, EC1N 8TE United Kin...  not found
# 215                                       Waltham, MA   not found
# 217  5th Floor West 1 London Bridge London, SE1 9BG...  not found
# 221      6 Bevis Marks London, EC3A 7BA United Kingdom  not found
# 225  28, Sin Ming Lane #01-143, Midview City Singap...      57397
# 226  33rd Floor, 689 Bhiraj Tower EmQuartier, Sukhu...      10110
# 227                                 San Francisco, CA   not found
# 229  116 New Montgomery St Suite 820 San Francisco,...  not found
#
#                 City
# 0               None
# 1               None
# 3               None
# 5               None
# 9               None
# 10              None
# 14              None
# 16              None
# 20          New York
# 23              None
# 27   Fort Lauderdale
# 28              None
# 34           Mankato
# 42              None
# 44              None
# 45              None
# 46           Fairfax
# 48              None
# 51              None
# 59        Broomfield
# 60       Playa Vista
# 66              None
# 75              None
# 77              None
# 79              None
# 80              None
# 84              None
# 87              None
# 89              None
# 92              None
# ..               ...
# 128             None
# 131    Mountain View
# 132      Pine Island
# 134      Saint Louis
# 140             None
# 150             None
# 153             None
# 154             None
# 155             None
# 162  North Las Vegas
# 171             None
# 174             None
# 176           Sabula
# 184             None
# 185             None
# 187             None
# 188             None
# 189             None
# 195             None
# 197             None
# 198             None
# 201             None
# 207             None
# 215             None
# 217             None
# 221             None
# 225             None
# 226         New York
# 227             None
# 229             None
#
# [72 rows x 3 columns]

# %%
def get_country(row):
    regex = re.compile("|".join(country_list), flags = re.I)
    # address_check == True means city is cross-checked. 
    # This is only possible for US cities
    if row["address_check"]:
        return "United States"
    else:
        if not isinstance(row["Location"], float):
            match = re.search(regex, row["Location"])
            if match:
                return match.group(0)
            else:
                return "not found"
        else:
            return "not found"

data["Country"] = data.apply(lambda location: get_country(location), axis = 1)

# %%
data[data["Country"] == "not found"][["Company","Location","zip_code" ,"City"]]
# Out:
#        Company                                           Location   zip_code  \
# 79   Ridibooks  Urban Bench 10th, Teheranro 325 Gangnamgu Seou...  not found
# 215     Cazena                                       Waltham, MA   not found
# 227     Narvar                                 San Francisco, CA   not found
#
#      City
# 79   None
# 215  None
# 227  None

# %%
# input country names
def input_countries(row):
    if row.Country == "not found":
        if row.Company == "Ridibooks":
            return "Korea"
        elif row.Company == "Cazena":
            return "United States"
        elif row.Company == "Narvar":
            return "United States"
    else:
        return row.Country
    
data.Country = data.apply(lambda row: input_countries(row), axis = 1)

# %%
# confirm the change
data[data["Country"] == "not found"][["Company","Location","zip_code" ,"City"]]
# Out:
# Empty DataFrame
# Columns: [Company, Location, zip_code, City]
# Index: []

# %%
mask = (data["Country"] == "United States") & (data["address_check"] == False)
data.loc[mask][["Location","zip_code" ,"City"]].shape
# Out:
# (18, 3)

# %%
data.loc[mask][["CompanyName","Location","zip_code" ,"City", "Website"]]
# Out:
#             CompanyName                                           Location  \
# 9           Fugue, Inc.       47 E. All Saints Frederick, MD United States
# 27           Magic Leap  7500 W Sunrise Blvd Plantation, Florida 33322 ...
# 44                   2U                                      United States
# 51       Snapchat, Inc.          Ocean Front Walk Venice, CA United States
# 59   Oracle | Datalogix  10075 Westmoor Drive Suite 200 Westminster, CO...
# 60   The Honest Company  12130 Millennium Drive Los Angeles, CA 90094 U...
# 80         Sift Science                  . San Francisco, CA United States
# 89        Silent Circle                                      United States
# 125      PAX Labs, Inc.            Mission San Francisco, CA United States
# 131         SentinelOne  2513 E. Charleston Rd Palo Alto, California 94...
# 134      Varsity Tutors  101 S. Hanley Rd Suite 300 St. Louis, MO 63105...
# 153              CoreOS                    San Francisco, CA United States
# 185           Ticketfly         San Francisco CA, California United States
# 189      Coupa Software                       San Mateo, CA, United States
# 197            Formlabs                                      United States
# 215              Cazena                                       Waltham, MA
# 227              Narvar                                 San Francisco, CA
# 229        Opendoor.com  116 New Montgomery St Suite 820 San Francisco,...
#
#       zip_code             City                           Website
# 9    not found             None               http://www.fugue.co
# 27       33322  Fort Lauderdale  https://www.magicleap.com/#/join
# 44   not found             None                     http://2u.com
# 51   not found             None           http://www.snapchat.com
# 59       80021       Broomfield          http://www.datalogix.com
# 60       90094      Playa Vista             http://www.honest.com
# 80   not found             None        http://www.siftscience.com
# 89   not found             None     https://www.silentcircle.com/
# 125  not found             None               http://www.pax.com/
# 131      94043    Mountain View        http://www.sentinelone.com
# 134      63105      Saint Louis      http://www.varsitytutors.com
# 153  not found             None                https://coreos.com
# 185  not found             None          http://www.ticketfly.com
# 189  not found             None              http://www.coupa.com
# 197  not found             None               http://formlabs.com
# 215  not found             None             http://www.cazena.com
# 227  not found             None             http://www.narvar.com
# 229  not found             None               http://opendoor.com

# %%
mask = (data["Country"] == "United States") & (data["address_check"] == False) & (data["zip_code"] == "not found")
data.loc[mask][["CompanyName","Location","zip_code" ,"City", "Website"]]
# Out:
#         CompanyName                                           Location  \
# 9       Fugue, Inc.       47 E. All Saints Frederick, MD United States
# 44               2U                                      United States
# 51   Snapchat, Inc.          Ocean Front Walk Venice, CA United States
# 80     Sift Science                  . San Francisco, CA United States
# 89    Silent Circle                                      United States
# 125  PAX Labs, Inc.            Mission San Francisco, CA United States
# 153          CoreOS                    San Francisco, CA United States
# 185       Ticketfly         San Francisco CA, California United States
# 189  Coupa Software                       San Mateo, CA, United States
# 197        Formlabs                                      United States
# 215          Cazena                                       Waltham, MA
# 227          Narvar                                 San Francisco, CA
# 229    Opendoor.com  116 New Montgomery St Suite 820 San Francisco,...
#
#       zip_code  City                        Website
# 9    not found  None            http://www.fugue.co
# 44   not found  None                  http://2u.com
# 51   not found  None        http://www.snapchat.com
# 80   not found  None     http://www.siftscience.com
# 89   not found  None  https://www.silentcircle.com/
# 125  not found  None            http://www.pax.com/
# 153  not found  None             https://coreos.com
# 185  not found  None       http://www.ticketfly.com
# 189  not found  None           http://www.coupa.com
# 197  not found  None            http://formlabs.com
# 215  not found  None          http://www.cazena.com
# 227  not found  None          http://www.narvar.com
# 229  not found  None            http://opendoor.com

# %%
# from google search
from get_company_address import *

# from company website
from get_location_from_company_website import *

# from bloomberg profile
from get_company_address_from_bloomberg import *

def rewrite_location(row):
    if (row["Country"] == "United States") & (row["address_check"] == False) & (row["zip_code"] == "not found"):
        result = get_company_address(row.CompanyName)
        
        if result != "not found":
            print ("done")
            return result
        else:
            result = get_location_trials(row.Website)
            
            if result != "not found":
                print ("done")
                return result
            else:
                result = get_address_from_bloomberg_merged(row.CompanyName)
                if result:
                    print ("done")
                    return result
                else:
                    print ("done")
                    return row.Location
                       
    else:
        print ("pass")
        return row.Location
    
data.Location = data.apply(lambda row: rewrite_location(row), axis = 1)
# Out:
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# 47 E All Saints St, Frederick, MD 21701
# done
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# 60 Chelsea Piers #6020, New York, NY 10011
# done
# pass
# pass
# pass
# pass
# pass
# pass
# not found
# not found
# move onto to second trial
# not found
# move onto to third trial
# not found
# https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=224055283
# 63 Market Street Venice, CA 90291 United States
# done
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# 123 Mission St #2000, San Francisco, CA 94105
# done
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# not found
# Fairfax, VA 22033
# done
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# 660 Alabama St, San Francisco, CA 94110
# done
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# 101 New Montgomery St, San Francisco, CA 94105
# done
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# 111 Townsend St, San Francisco, CA 94107
# done
# pass
# pass
# pass
# 1855 S Grant St, San Mateo, CA 94402
# done
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# 35 Medford St #201, Somerville, MA 02143
# done
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# 1601 Trapelo Rd, Waltham, MA 02451
# done
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# 633 Folsom St #200, San Francisco, CA 94107
# done
# pass
# 116 New Montgomery St #820, San Francisco, CA 94105
# done
# pass
# pass

# %%
mask = (data["Country"] == "United States") & (data["address_check"] == False) & (data["zip_code"] == "not found")
data.loc[mask][["CompanyName","Location","zip_code" ,"City", "Website"]]
# Out:
#         CompanyName                                           Location  \
# 9       Fugue, Inc.            47 E All Saints St, Frederick, MD 21701
# 44               2U         60 Chelsea Piers #6020, New York, NY 10011
# 51   Snapchat, Inc.    63 Market Street Venice, CA 90291 United States
# 80     Sift Science      123 Mission St #2000, San Francisco, CA 94105
# 89    Silent Circle                                  Fairfax, VA 22033
# 125  PAX Labs, Inc.            660 Alabama St, San Francisco, CA 94110
# 153          CoreOS     101 New Montgomery St, San Francisco, CA 94105
# 185       Ticketfly           111 Townsend St, San Francisco, CA 94107
# 189  Coupa Software               1855 S Grant St, San Mateo, CA 94402
# 197        Formlabs           35 Medford St #201, Somerville, MA 02143
# 215          Cazena                 1601 Trapelo Rd, Waltham, MA 02451
# 227          Narvar        633 Folsom St #200, San Francisco, CA 94107
# 229    Opendoor.com  116 New Montgomery St #820, San Francisco, CA ...
#
#       zip_code  City                        Website
# 9    not found  None            http://www.fugue.co
# 44   not found  None                  http://2u.com
# 51   not found  None        http://www.snapchat.com
# 80   not found  None     http://www.siftscience.com
# 89   not found  None  https://www.silentcircle.com/
# 125  not found  None            http://www.pax.com/
# 153  not found  None             https://coreos.com
# 185  not found  None       http://www.ticketfly.com
# 189  not found  None           http://www.coupa.com
# 197  not found  None            http://formlabs.com
# 215  not found  None          http://www.cazena.com
# 227  not found  None          http://www.narvar.com
# 229  not found  None            http://opendoor.com

# %%
# assign zip code, city to the new addresses
# conduct address_check

data["zip_code"] = data.Location.apply(lambda address: get_zipcode(str(address)))

data["City"] = data.zip_code.apply(lambda zip_code: get_city(zip_code))

data["address_check"] = data.apply(lambda row: check_city_match(row), axis = 1)

# %%
# confirm the change
mask = (data["Country"] == "United States") & (data["address_check"] == False)
data.loc[mask][["CompanyName","Location","zip_code" ,"City", "Website"]]
# Out:
#             CompanyName                                           Location  \
# 27           Magic Leap  7500 W Sunrise Blvd Plantation, Florida 33322 ...
# 59   Oracle | Datalogix  10075 Westmoor Drive Suite 200 Westminster, CO...
# 60   The Honest Company  12130 Millennium Drive Los Angeles, CA 90094 U...
# 131         SentinelOne  2513 E. Charleston Rd Palo Alto, California 94...
# 134      Varsity Tutors  101 S. Hanley Rd Suite 300 St. Louis, MO 63105...
#
#     zip_code             City                           Website
# 27     33322  Fort Lauderdale  https://www.magicleap.com/#/join
# 59     80021       Broomfield          http://www.datalogix.com
# 60     90094      Playa Vista             http://www.honest.com
# 131    94043    Mountain View        http://www.sentinelone.com
# 134    63105      Saint Louis      http://www.varsitytutors.com

# %%
def get_state(zip_code):
    search = ZipcodeSearchEngine()
    if zip_code != "not found":
        myzip = search.by_zipcode(zip_code)
        if myzip:
            return myzip["State"]
        else:
            myzip = zipcode.isequal(zip_code)
            if myzip:
                return myzip.state
            else:
                return None
    else:
        return None
        
data["State"] = data.zip_code.apply(lambda zip_code: get_state(zip_code))

# %%
def get_latitude(zip_code):
    search = ZipcodeSearchEngine()
    if zip_code != "not found":
        myzip = search.by_zipcode(zip_code)
#         myzip = None
        if myzip:
            return myzip["Latitude"]
        else:
            myzip = zipcode.isequal(zip_code)
            if myzip:
                return myzip.lat
            else:
                return None
    else:
        return None
    
data["latitude"] = data.zip_code.apply(lambda zip_code: get_latitude(zip_code))

# %%
def get_longitude(zip_code):
    search = ZipcodeSearchEngine()
    if zip_code != "not found":
        myzip = search.by_zipcode(zip_code)
#         myzip = None
        if myzip:
            return myzip["Longitude"]
        else:
            myzip = zipcode.isequal(zip_code)
            if myzip:
                return myzip.lon
            else:
                return None
    else:
        return None
    
data["longitude"] = data.zip_code.apply(lambda zip_code: get_longitude(zip_code))

# %%
data.apply(lambda row: sum(row.isnull()))
# Out:
# title                   0
# link                    0
# excerpt                 0
# published_at            0
# funding_round          12
# money_raised            0
# Company                 0
# money_raised_float      0
# linkedin_link           0
# Company_at_Linkedin     0
# CompanyName             0
# Specialties            33
# Industry                0
# Website                 0
# Location                0
# CompanySize             0
# Description             0
# Founded                 5
# Also-viewed             0
# zip_code                0
# City                   46
# address_check           0
# Country                 0
# State                  46
# latitude               46
# longitude              46
# dtype: int64

# %%
data[data["State"].isnull() ]
# Out:
#                                                  title  \
# 0    Indian online lending platform Capital Float r...
# 1    Carwow, a UK startup that helps you buy a new ...
# 3    Blowing up the re-location industry, Move Guid...
# 5    After bump in the road, Movinga raises ?17M Se...
# 10   Social Intelligence Startup Brandwatch Raises ...
# 14   Restaurant Delivery Startup Deliveroo Raises $...
# 16   India?s BankBazaar Raises $60M Series C Led By...
# 23   eGym raises $45M Series C for cloud-connected ...
# 28   Lending Platform China Rapid Finance Raises $3...
# 42   Ostrovok Raises New $12M Series C Round To Exp...
# 45   BonitaSoft Raises $13M Series C For Its Open S...
# 48   WorldStores Raises $15M Series C To Build Out ...
# 66   Wonga raises £73m in Series C funding to doubl...
# 75   Shopify Raises $100M To Drop The ?E? And Becom...
# 77   Breather raises $40 million for stylish worksp...
# 79   Korean e-book service Ridibooks scores $20M Se...
# 84   Canada?s Assent Compliance raises $31.4M Serie...
# 87   Midokura raises $20M Series B round for its ne...
# 92   Moglix raises $12M Series B to digitize India?...
# 97   Push Doctor, an app that lets you video call a...
# 99   Iyzico, a Turkish online payments company and ...
# 103  Flash Sales Site SportPursuit Scores £9.5M Ser...
# 104  Healthcare booking platform DocPlanner raises ...
# 108  Yoyo Wallet raises £12M Series B led by Metro ...
# 113  Showpad closes $50M Series C to keep growing i...
# 117  German consumer loans marketplace Finanzcheck ...
# 121  Argentinian E-Commerce Leader Avenida Gets $30...
# 124  LimeRoad, A Fashion Scrapbooking Site Based In...
# 127      Seatwave wins $25m Series C funding to expand
# 128  Quiqup, a London-based on-demand delivery star...
# 140  Full Details On Mint's $14 Million Series C Round
# 150  ScribbleLive Closes $12M Series C, Eyes Acquis...
# 154  Appear Here, a marketplace for short-term reta...
# 155  Online lender Kreditech closes out Series C at...
# 171  Confirmed: Truecaller Scores $60 Million In Se...
# 174  Mobile Media Company Affle Raises $10M+ From D...
# 184  Xeneta raises $12M Series B to crack open ocea...
# 187  Huddle Lands $24M Series C To Go Big On Enterp...
# 188  Indian E-commerce Logistics Startup Delhivery ...
# 195  Velocity raises $22.5M Series B to build â??Ub...
# 198  TrialReach Raises $13.5M Series B To Match Pat...
# 201  Musement, a â??digital travel companionâ?? and...
# 207               Skinkers Raises $16 Million Series B
# 217  Blippar augmented reality search engine raises...
# 221  Business Currency Exchange Startup Kantox Rais...
# 225   GrabTaxi Raises $15M Series B Led By GGV Capital
#
#                                                   link  \
# 0    https://techcrunch.com/2017/08/21/indian-onlin...
# 1    https://techcrunch.com/2017/07/30/carwow-serie...
# 3    https://techcrunch.com/2017/07/11/blowing-up-t...
# 5    https://techcrunch.com/2016/12/08/on-the-movin...
# 10   https://techcrunch.com/2015/10/29/social-intel...
# 14   https://techcrunch.com/2015/07/27/series-c-del...
# 16       https://techcrunch.com/2015/07/02/bankbazaar/
# 23             https://techcrunch.com/2016/03/21/egym/
# 28   https://techcrunch.com/2015/07/29/china-rapid-...
# 42   https://techcrunch.com/2014/06/18/ostrovok-rai...
# 45              https://techcrunch.com/2013/05/16/bpm/
# 48   https://techcrunch.com/2013/06/03/worldstores-...
# 66   https://techcrunch.com/2011/02/16/wonga-raises...
# 75   https://techcrunch.com/2013/12/11/shopify-100-...
# 77   https://techcrunch.com/2016/12/07/breather-rai...
# 79   https://techcrunch.com/2017/06/15/korean-e-boo...
# 84   https://techcrunch.com/2017/07/14/canadas-asse...
# 87   https://techcrunch.com/2016/06/08/midokura-rai...
# 92   https://techcrunch.com/2017/07/06/moglix-raise...
# 97   https://techcrunch.com/2017/07/05/push-doctor-...
# 99   https://techcrunch.com/2017/04/03/iyzico-a-tur...
# 103  https://techcrunch.com/2015/11/22/flash-sales-...
# 104    https://techcrunch.com/2017/05/23/docplanner-d/
# 108  https://techcrunch.com/2017/06/25/yoyo-wallet-...
# 113  https://techcrunch.com/2016/05/19/showpad-clos...
# 117  https://techcrunch.com/2016/04/06/german-consu...
# 121  https://techcrunch.com/2015/11/20/argentinian-...
# 124  https://techcrunch.com/2015/03/30/limeroad-ser...
# 127  https://techcrunch.com/2008/02/11/seatwave-win...
# 128  https://techcrunch.com/2017/05/23/quiqup-serie...
# 140  https://techcrunch.com/2009/08/12/full-details...
# 150  https://techcrunch.com/2014/10/02/scribblelive...
# 154  https://techcrunch.com/2017/05/17/appear-here-...
# 155  https://techcrunch.com/2016/03/23/online-lende...
# 171  https://techcrunch.com/2014/10/08/confirmed-tr...
# 174  https://techcrunch.com/2011/10/04/mobile-media...
# 184  https://techcrunch.com/2017/02/08/xeneta-serie...
# 187  https://techcrunch.com/2012/05/24/huddle-25-mi...
# 188  https://techcrunch.com/2015/05/06/delhivery-se...
# 195  https://techcrunch.com/2016/08/30/velocity-ser...
# 198      https://techcrunch.com/2015/02/05/trialreach/
# 201  https://techcrunch.com/2016/11/15/for-your-mus...
# 207  https://techcrunch.com/2007/10/29/skinkers-rai...
# 217  https://techcrunch.com/2016/03/02/blippar-augm...
# 221  https://techcrunch.com/2015/05/27/kantox-serie...
# 225  https://techcrunch.com/2014/05/28/grabtaxi-rai...
#
#                                                excerpt published_at  \
# 0    Capital Float, which claims to be the largest ...    8/21/2017
# 1    Carwow, a platform that helps you buy a new ca...    7/30/2017
# 3    Whatever any country leader says about banning...    7/11/2017
# 5    Berlin's startup scene is probably the most go...    12/8/2016
# 10   Social media is officially eating Internet, an...   10/29/2015
# 14   Deliveroo, the on-demand startup that offers f...    7/27/2015
# 16   BankBazaar, a startup that lets Indian consume...     7/2/2015
# 23   eGym, the Munich-based startup that offers clo...    3/21/2016
# 28   China Rapid Finance, which claims to be the co...    7/29/2015
# 42   Ostrovok.ru, the Russian accommodation booking...    6/18/2014
# 45   BonitaSoft, a provider of an open source busin...    5/16/2013
# 48   WorldStores, a U.K.-based online retailer of h...     6/3/2013
# 66   Wonga, the short-loans company which uses a re...    2/16/2011
# 75   Ottawa-based Shopify has already raised a cons...   12/11/2013
# 77   A mobile app that lets users find and book sty...    12/7/2016
# 79   E-book sales may be declining in the U.S. and ...    6/15/2017
# 84   Assent Compliance, an Ottawa-based startup, is...    7/14/2017
# 87   Network virtualization specialist Midokura tod...     6/8/2016
# 92   Moglix launched in 2015 as an online store for...     7/6/2017
# 97   Push Doctor, a U.K.-based startup that lets yo...     7/5/2017
# 99   Iyzico, the Turkish fintech startup to let e-c...     4/3/2017
# 103  SportPursuit, the flash sales site for 'premiu...   11/22/2015
# 104  DocPlanner, the European online booking platfo...    5/23/2017
# 108  The race to digitise the loyalty card just got...    6/25/2017
# 113  SaaS startup Showpad which has built a platfor...    5/19/2016
# 117  In Europe, London tends to grab most of the fi...     4/6/2016
# 121  Avenida is set on cementing its leadership pos...   11/20/2015
# 124  LimeRoad, a New Delhi-based site that lets use...    3/30/2015
# 127  Ticket reseller Seatwave has taken $25 million...    2/11/2008
# 128  Quiqup, a London-based delivery startup that o...    5/23/2017
# 140  Mint, the popular personal finance site that w...    8/12/2009
# 150  ScribbleLive is today announcing the closing o...    10/2/2014
# 154  Appear Here, a marketplace for short-term reta...    5/17/2017
# 155  Kreditech -- the German startup that offers lo...    3/23/2016
# 171  Truecaller has just announced the raise of a $...    10/8/2014
# 174  Singapore-headquartered mobile media and adver...    10/4/2011
# 184  Xeneta, the Oslo, Norway-based startup that of...     2/8/2017
# 187  Huddle, the six-year-old company that makes cl...    5/24/2012
# 188  In yet another vote of confidence for India?s ...     5/6/2015
# 195  Digital hospitality platform Velocity announce...    8/30/2016
# 198  TrialReach is an interesting startup on a numb...     2/5/2015
# 201  Musement, a "digital travel companion" that le...   11/15/2016
# 207  Skinkers, the UK company that is building a P2...   10/29/2007
# 217  Blippar, the AR company that lets you see extr...     3/2/2016
# 221  Another London-headquartered fintech startup, ...    5/27/2015
# 225  GrabTaxi, the taxi-calling app that claims to ...    5/28/2014
#
#     funding_round money_raised                                  Company  \
# 0        Series C        $45 M                            Capital Float
# 1        Series C        $39 M                                   Carwow
# 3        Series C        $48 M                              Move Guides
# 5        Series C      $20.2 M                                  Movinga
# 10       Series C        $33 M                               Brandwatch
# 14       Series C        $70 M                                Deliveroo
# 16       Series C        $60 M                       India?s BankBazaar
# 23       Series C        $45 M                                     eGym
# 28       Series C        $35 M                      China Rapid Finance
# 42       Series C        $12 M                                 Ostrovok
# 45       Series C        $13 M                               BonitaSoft
# 48       Series C        $15 M                              WorldStores
# 66       Series C      $94.2 M                                    Wonga
# 75       Series C       $100 M                                  Shopify
# 77       Series C        $40 M                                 Breather
# 79       Series C        $20 M                                Ridibooks
# 84       Series B      $31.4 M               Canada?s Assent Compliance
# 87       Series B        $20 M                                 Midokura
# 92       Series B        $12 M                                   Moglix
# 97       Series B      $26.1 M                              Push Doctor
# 99       Series C        $15 M                                   Iyzico
# 103      Series C      $12.3 M                             SportPursuit
# 104      Series D      $17.8 M                               DocPlanner
# 108      Series B      $15.5 M                              Yoyo Wallet
# 113      Series C        $50 M                                  Showpad
# 117      Series C      $39.3 M                              Finanzcheck
# 121      Series C        $30 M                                  Avenida
# 124      Series C        $30 M                                 LimeRoad
# 127      Series C        $25 M                                 Seatwave
# 128      Series B      $25.8 M                                   Quiqup
# 140      Series C        $14 M                   Full Details On Mint's
# 150      Series C        $12 M                             ScribbleLive
# 154      Series B        $12 M                              Appear Here
# 155      Series C       $103 M                                Kreditech
# 171      Series C        $60 M                               Truecaller
# 174           NaN        $10 M                                    Affle
# 184      Series B        $12 M                                   Xeneta
# 187      Series C        $24 M                                   Huddle
# 188      Series D        $85 M                                Delhivery
# 195      Series B      $22.5 M                                 Velocity
# 198      Series B      $13.5 M                               TrialReach
# 201      Series B        $10 M                                 Musement
# 207      Series B        $16 M                                 Skinkers
# 217      Series D        $54 M  Blippar augmented reality search engine
# 221      Series B        $11 M                                   Kantox
# 225      Series B        $15 M                                 GrabTaxi
#
#      money_raised_float                                      linkedin_link  \
# 0                  45.0     https://www.linkedin.com/company/capital-float
# 1                  39.0            https://www.linkedin.com/company/carwow
# 3                  48.0       https://www.linkedin.com/company/move-guides
# 5                  20.2      https://www.linkedin.com/company/movinga-gmbh
# 10                 33.0        https://www.linkedin.com/company/brandwatch
# 14                 70.0         https://www.linkedin.com/company/deliveroo
# 16                 60.0       https://www.linkedin.com/company/bank_bazaar
# 23                 45.0         https://www.linkedin.com/company/egym-gmbh
# 28                 35.0  https://www.linkedin.com/company/china-rapid-f...
# 42                 12.0       https://www.linkedin.com/company/ostrovok-ru
# 45                 13.0        https://www.linkedin.com/company/bonitasoft
# 48                 15.0       https://www.linkedin.com/company/worldstores
# 66                 94.2         https://www.linkedin.com/company/wonga-com
# 75                100.0           https://www.linkedin.com/company/shopify
# 77                 40.0          https://www.linkedin.com/company/breather
# 79                 20.0         https://www.linkedin.com/company/ridibooks
# 84                 31.4  https://www.linkedin.com/company/assent-compli...
# 87                 20.0          https://www.linkedin.com/company/midokura
# 92                 12.0            https://www.linkedin.com/company/moglix
# 97                 26.1            https://www.linkedin.com/company/pushdr
# 99                 15.0     https://www.linkedin.com/company/iyzi-payments
# 103                12.3      https://www.linkedin.com/company/sportpursuit
# 104                17.8        https://www.linkedin.com/company/docplanner
# 108                15.5       https://www.linkedin.com/company/yoyo-wallet
# 113                50.0           https://www.linkedin.com/company/showpad
# 117                39.3    https://www.linkedin.com/company/finanzcheck-de
# 121                30.0           https://www.linkedin.com/company/avenida
# 124                30.0      https://www.linkedin.com/company/limeroad-com
# 127                25.0          https://www.linkedin.com/company/seatwave
# 128                25.8            https://www.linkedin.com/company/quiqup
# 140                14.0       https://www.linkedin.com/company/we-are-mint
# 150                12.0      https://www.linkedin.com/company/scribblelive
# 154                12.0       https://www.linkedin.com/company/appear-here
# 155               103.0  https://www.linkedin.com/company/kreditech-hol...
# 171                60.0  https://www.linkedin.com/company/true-software...
# 174                10.0             https://www.linkedin.com/company/affle
# 184                12.0         https://www.linkedin.com/company/xeneta-as
# 187                24.0            https://www.linkedin.com/company/huddle
# 188                85.0         https://www.linkedin.com/company/delhivery
# 195                22.5         https://www.linkedin.com/company/velocity-
# 198                13.5        https://www.linkedin.com/company/trialreach
# 201                10.0          https://www.linkedin.com/company/musement
# 207                16.0          https://www.linkedin.com/company/skinkers
# 217                54.0           https://www.linkedin.com/company/blippar
# 221                11.0            https://www.linkedin.com/company/kantox
# 225                15.0           https://www.linkedin.com/company/grabapp
#
#               Company_at_Linkedin    ...     \
# 0                   capital float    ...
# 1                          carwow    ...
# 3                     move guides    ...
# 5                    movinga gmbh    ...
# 10                     brandwatch    ...
# 14                      deliveroo    ...
# 16                    bank_bazaar    ...
# 23                      egym gmbh    ...
# 28            china rapid finance    ...
# 42                    ostrovok ru    ...
# 45                     bonitasoft    ...
# 48                    worldstores    ...
# 66                      wonga com    ...
# 75                        shopify    ...
# 77                       breather    ...
# 79                      ridibooks    ...
# 84          assent compliance inc    ...
# 87                       midokura    ...
# 92                         moglix    ...
# 97                         pushdr    ...
# 99                  iyzi payments    ...
# 103                  sportpursuit    ...
# 104                    docplanner    ...
# 108                   yoyo wallet    ...
# 113                       showpad    ...
# 117                finanzcheck de    ...
# 121                       avenida    ...
# 124                  limeroad com    ...
# 127                      seatwave    ...
# 128                        quiqup    ...
# 140                   we are mint    ...
# 150                  scribblelive    ...
# 154                   appear here    ...
# 155    kreditech holding ssl gmbh    ...
# 171  true software scandinavia ab    ...
# 174                         affle    ...
# 184                     xeneta as    ...
# 187                        huddle    ...
# 188                     delhivery    ...
# 195                     velocity     ...
# 198                    trialreach    ...
# 201                      musement    ...
# 207                      skinkers    ...
# 217                       blippar    ...
# 221                        kantox    ...
# 225                       grabapp    ...
#
#                                            Description Founded  \
# 0    Capital Float is a digital finance company ser...  2013.0
# 1    carwow is the most convenient, stress-free way...  2013.0
# 3    MOVE Guides helps HR teams move their employee...  2011.0
# 5    Movinga is Europeâ??s fastest growing online p...  2015.0
# 10   Brandwatch is the worldâ??s leading enterprise...  2007.0
# 14   Deliveroo is on a mission to transform the way...  2012.0
# 16   BankBazaar is the worldâ??s first neutral onli...  2008.0
# 23   eGym develops professional fitness equipment f...  2010.0
# 28   China Rapid Finance (NYSE:XRF) operates one of...  2001.0
# 42   Ostrovok.ru is a rapidly-growing consumer trav...  2010.0
# 45   Bonitasoft helps innovative companies worldwid...  2009.0
# 48   Established in 2008, Worldstores is now the UK...  2004.0
# 66   We are an international finance company using ...  2007.0
# 75   Shopify is a leading cloud-based, multichannel...  2006.0
# 77   Breather creates peaceful, practical and beaut...  2012.0
# 79   ë¦¬ë??ì£¼ì??í??ì?¬ë?? êµ­ë?´ 1ë?± ì ?ì??ì±?ì??...  2008.0
# 84   Assent Compliance is an elite provider of cons...  2005.0
# 87   A global startup with offices in San Francisco...  2010.0
# 92   We are an Asia-based E-commerce company intens...  2015.0
# 97   Push For Health.\r\r\nPush For Life.\r\r\nPush...  2013.0
# 99   iyzico was founded in 2012 with a vision to be...  2012.0
# 103  SportPursuit is the UKâ??s first private-sale ...  2011.0
# 104  DocPlanner is the biggest european booking pla...  2011.0
# 108  Yoyo is the fastest growing mobile wallet in E...  2013.0
# 113  Showpad delivers the worldâ??s most intuitive ...  2011.0
# 117  FINANZCHECK.de ist das fÃ¼hrende, unabhÃ¤ngige...  2010.0
# 121  Avenida, we increase certainty\r\r\n\r\r\nOur ...  2007.0
# 124  LimeRoad is a fun and exciting way to find gor...  2012.0
# 127  Ticketmaster, a proud division of Live Nation ...  2006.0
# 128  Quiqup is a London-based company that offers o...  2014.0
# 140  We Are Mint (www.we-are-mint.co.uk) is a bouti...  2016.0
# 150  ScribbleLive is the worldâ??s leading Content ...  2008.0
# 154  Appear Here is the leading online marketplace ...  2013.0
# 155  Kreditech Groupâ??s mission is to improve fina...  2012.0
# 171  Truecaller is a leading search technology comp...  2009.0
# 174  Affle is a Singapore headquartered â??Mobile A...  2006.0
# 184  Powered by big data analytics, the Xeneta plat...  2012.0
# 187  Huddle is the enterprise document collaboratio...  2006.0
# 188  Delhivery is India's largest  e-commerce enabl...  2011.0
# 195  We are your Temporary and Permanent Business S...  2008.0
# 198  TrialReach is a free online platform that is t...  2009.0
# 201  Local wherever you go\r\r\n\r\r\nMusement help...  2012.0
# 207  Since 2000, Skinkers has pioneered the use of ...  2000.0
# 217  Blippar is a leading technology company specia...  2011.0
# 221  Kantox is a multinational fintech company offe...  2011.0
# 225  Grab is more than just the leading ride-hailin...  2012.0
#
#                                            Also-viewed   zip_code  City  \
# 0    {'Lendingkart': 'https://www.linkedin.com/comp...      56008  None
# 1    {'carwow GmbH': 'https://www.linkedin.com/comp...  not found  None
# 3    {'Workable': 'https://www.linkedin.com/company...  not found  None
# 5    {'Move24 Group GmbH': 'https://www.linkedin.co...      10437  None
# 10   {'Synthesio': 'https://www.linkedin.com/compan...  not found  None
# 14   {'foodora': 'https://www.linkedin.com/company/...  not found  None
# 16   {'PolicyBazaar.com': 'https://www.linkedin.com...      60000  None
# 23   {'eGym Benelux': 'https://www.linkedin.com/com...      80333  None
# 28   {'é??é??æ??': 'https://www.linkedin.com/compan...      20033  None
# 42   {'OneTwoTrip': 'https://www.linkedin.com/compa...  not found  None
# 45   {'Bizagi': 'https://www.linkedin.com/company/b...      92100  None
# 48   {'achica': 'https://www.linkedin.com/company/a...  not found  None
# 66   {'Zopa': 'https://www.linkedin.com/company/zop...  not found  None
# 75   {'Shopify Plus': 'https://www.linkedin.com/com...  not found  None
# 77   {'Hopper': 'https://www.linkedin.com/company/h...  not found  None
# 79   {'RIDI Lighting': 'https://www.linkedin.com/co...  not found  None
# 84   {'Assent Consulting': 'https://www.linkedin.co...  not found  None
# 87   {'PLUMgrid Inc.': 'https://www.linkedin.com/co...  not found  None
# 92   {'Industrybuying.com': 'https://www.linkedin.c...      13995  None
# 97   {'MRJ Recruitment': 'https://www.linkedin.com/...  not found  None
# 99   {'Hepsiburada.com': 'https://www.linkedin.com/...      34732  None
# 103  {'SECRETSALES.com': 'https://www.linkedin.com/...  not found  None
# 104  {'Doctoralia': 'https://www.linkedin.com/compa...  not found  None
# 108  {'GoCardless': 'https://www.linkedin.com/compa...  not found  None
# 113  {'In The Pocket': 'https://www.linkedin.com/co...  not found  None
# 117  {'Finanzcheck GmbH': 'https://www.linkedin.com...      22765  None
# 121  {'Grupo Avenida (Lojas Avenida e Giovanna CalÃ...  not found  None
# 124  {'KOOVS.COM': 'https://www.linkedin.com/compan...      12200  None
# 127  {'Ticketmaster': 'https://www.linkedin.com/com...  not found  None
# 128  {'Stuart': 'https://www.linkedin.com/company/s...  not found  None
# 140  {'Re:Work': 'https://www.linkedin.com/company/...  not found  None
# 150  {'Visually': 'https://www.linkedin.com/company...  not found  None
# 154  {'We Are Pop Up': 'https://www.linkedin.com/co...  not found  None
# 155  {'N26': 'https://www.linkedin.com/company/n26'...      20459  None
# 171  {'Spotify': 'https://www.linkedin.com/company/...      11143  None
# 174  {'Affle AppStudioz': 'https://www.linkedin.com...      11851  None
# 184  {'Freightos': 'https://www.linkedin.com/compan...  not found  None
# 187  {'MOO': 'https://www.linkedin.com/company/moo-...  not found  None
# 188  {'Ecom Express Private Limited': 'https://www....      12200  None
# 195  {'Velocity Technology Solutions': 'https://www...  not found  None
# 198  {'HealthUnlocked': 'https://www.linkedin.com/c...  not found  None
# 201  {'Satispay': 'https://www.linkedin.com/company...  not found  None
# 207  {'Konetic': 'https://www.linkedin.com/company/...  not found  None
# 217  {'Layar': 'https://www.linkedin.com/company/la...  not found  None
# 221  {'Ebury': 'https://www.linkedin.com/company/eb...  not found  None
# 225  {'Lazada Group': 'https://www.linkedin.com/com...      57397  None
#
#     address_check         Country  State latitude longitude
# 0           False           India   None      NaN       NaN
# 1           False  United Kingdom   None      NaN       NaN
# 3           False  United Kingdom   None      NaN       NaN
# 5           False         Germany   None      NaN       NaN
# 10          False  United Kingdom   None      NaN       NaN
# 14          False  United Kingdom   None      NaN       NaN
# 16          False           India   None      NaN       NaN
# 23          False         Germany   None      NaN       NaN
# 28          False           China   None      NaN       NaN
# 42          False          Russia   None      NaN       NaN
# 45          False          France   None      NaN       NaN
# 48          False  United Kingdom   None      NaN       NaN
# 66          False  United Kingdom   None      NaN       NaN
# 75          False          Canada   None      NaN       NaN
# 77          False          Canada   None      NaN       NaN
# 79          False           Korea   None      NaN       NaN
# 84          False          Canada   None      NaN       NaN
# 87          False           Japan   None      NaN       NaN
# 92          False       Singapore   None      NaN       NaN
# 97          False  United Kingdom   None      NaN       NaN
# 99          False          Turkey   None      NaN       NaN
# 103         False  United Kingdom   None      NaN       NaN
# 104         False          Poland   None      NaN       NaN
# 108         False  United Kingdom   None      NaN       NaN
# 113         False         Belgium   None      NaN       NaN
# 117         False         Germany   None      NaN       NaN
# 121         False         Denmark   None      NaN       NaN
# 124         False           India   None      NaN       NaN
# 127         False  United Kingdom   None      NaN       NaN
# 128         False  United Kingdom   None      NaN       NaN
# 140         False          Israel   None      NaN       NaN
# 150         False          Canada   None      NaN       NaN
# 154         False  United Kingdom   None      NaN       NaN
# 155         False         Germany   None      NaN       NaN
# 171         False          Sweden   None      NaN       NaN
# 174         False       Singapore   None      NaN       NaN
# 184         False          Norway   None      NaN       NaN
# 187         False  United Kingdom   None      NaN       NaN
# 188         False           India   None      NaN       NaN
# 195         False     New Zealand   None      NaN       NaN
# 198         False  United Kingdom   None      NaN       NaN
# 201         False           Italy   None      NaN       NaN
# 207         False  United Kingdom   None      NaN       NaN
# 217         False  United Kingdom   None      NaN       NaN
# 221         False  United Kingdom   None      NaN       NaN
# 225         False       Singapore   None      NaN       NaN
#
# [46 rows x 26 columns]

# %%
data.to_csv("article_after_processing8.csv", index = False)
